# %%
import pandas as pd
url = 'https://nuhuskies.com/sports/womens-ice-hockey/stats/2023-24/connecticut/boxscore/12666'
nu_wih = pd.read_html(url)
len(nu_wih)
# Out:
# 14

# %%
# Now to build a big loop for all the games
opponents = ['penn-state', 'penn-state', 'liu', 'liu',
             'boston-university', 'boston-university', 'merrimack',
             'st-cloud-state', 'sacred-heart', 'holy-cross', 'holy-cross',
             'connecticut', 'connecticut', 'providence', 'providence',
             'vermont', 'boston-college', 'providence', 'boston-university',
             'yale', 'holy-cross', 'maine', 'maine', 'harvard', 'new-hampshire',
             'boston-university', 'merrimack', 'merrimack', 'new-hampshire',
             'new-hampshire', 'connecticut', 'maine', 'boston-college',
             'boston-college', 'vermont', 'vermont', 'merrimack', 'new-hampshire',
             'connecticut']
game_numbers = [12650, 12653, 12654, 12655, 12656, 12657, 12658,
                12660, 12662, 12663, 12664, 12665, 12666, 12668,
                12671, 12673, 12675, 12677, 12678, 12679, 12680,
                12681, 12682, 12683, 12684, 12685, 12686, 12687,
                12688, 12689, 12690, 12691, 12692, 12693, 12694,
                12695, 13051, 13103, 13104]

# %%
# Nested dictionary
full_dict = defaultdict(dict)

# The Loop
for idx in range(len(game_numbers)):
    url = f'https://nuhuskies.com/sports/womens-ice-hockey/stats/2023-24/{opponents[idx]}/boxscore/{game_numbers[idx]}'
    nu_wih = pd.read_html(url)

    # Initialize a dictionary with lists as default values (though lists are not needed here)
    test_dict = defaultdict(list)
    
    # Clean up the team names by removing "Winner " from the "Team" column in nu_wih[0]
    nu_wih[0].iloc[:, 0] = nu_wih[0].iloc[:, 0].str.replace("Winner  ", "")
    
    # Assign home and visit teams to the dictionary
    test_dict['home_team'] = nu_wih[0].loc[1, "Team"]
    test_dict['visit_team'] = nu_wih[0].loc[0, "Team"]
    
    # Extract linescores for home and visit teams
    home_linescore = nu_wih[0].iloc[1, 1:-1]
    visit_linescore = nu_wih[0].iloc[0, 1:-1]
    
    # Assign home linescore values to the dictionary
    for col in home_linescore.index:
        col2 = "home_" + col  # Create a key like "home_1st", "home_2nd", etc.
        test_dict[col2] = home_linescore[col]  # Direct assignment
    
    # Assign visit linescore values to the dictionary
    for col in visit_linescore.index:
        col2 = "visit_" + col  # Create a key like "visit_1st", "visit_2nd", etc.
        test_dict[col2] = visit_linescore[col]  # Direct assignment
    
    # Function to convert the time string (e.g., "02:30") into a timedelta object
    def convert_to_timedelta(time_str):
        minutes, seconds = map(int, time_str.split(':'))
        return timedelta(minutes=minutes, seconds=seconds)
    
    # Function to format timedelta as "MM:SS"
    def format_timedelta(td):
        total_seconds = int(td.total_seconds())
        minutes, seconds = divmod(total_seconds, 60)
        return f"{minutes:02}:{seconds:02}"
    
    # Process home team's power play stats by period from nu_wih[3]
    df_home = nu_wih[3].iloc[:-1, :]  # Exclude last row
    
    if 'Prd' in df_home.columns:
        for period in df_home['Prd'].unique():
            i = int(period[0])  # Extract the period number (e.g., 1st -> 1)
        
            # Filter the data for the specific period
            period_df = df_home[df_home['Prd'] == period]
            
            # Sum shots, opp-shots, and calculate total elapsed power play time
            shots_sum = period_df['Shots'].sum()
            opp_shots_sum = period_df['Opp-Shots'].sum()
            total_elapsed = sum(period_df['Elapsed'].apply(convert_to_timedelta), timedelta())
            total_elapsed_str = format_timedelta(total_elapsed)
            
            # Store the calculated values in the dictionary
            test_dict[f'home_pp_elapsed_{i}'] = total_elapsed_str
            test_dict[f'home_pp_shots_{i}'] = shots_sum
            test_dict[f'home_pp_oppshots_{i}'] = opp_shots_sum
    else:
        test_dict[f'home_pp_elapsed_{i}'] = '00:00'
        test_dict[f'home_pp_shots_{i}'] = 0
        test_dict[f'home_pp_oppshots_{i}'] = 0
        
    # Process visit team's power play stats by period from nu_wih[2]
    df_visit = nu_wih[2].iloc[:-1, :]  # Exclude last row
    
    if 'Prd' in df_visit.columns:
        for period in df_visit['Prd'].unique():
            i = int(period[0])  # Extract the period number
        
            # Filter the data for the specific period
            period_df = df_visit[df_visit['Prd'] == period]
            
            # Sum shots, opp-shots, and calculate total elapsed power play time
            shots_sum = period_df['Shots'].sum()
            opp_shots_sum = period_df['Opp-Shots'].sum()
            total_elapsed = sum(period_df['Elapsed'].apply(convert_to_timedelta), timedelta())
            total_elapsed_str = format_timedelta(total_elapsed)
            
            # Store the calculated values in the dictionary
            test_dict[f'visit_pp_elapsed_{i}'] = total_elapsed_str
            test_dict[f'visit_pp_shots_{i}'] = shots_sum
            test_dict[f'visit_pp_oppshots_{i}'] = opp_shots_sum
    else:
        test_dict[f'visit_pp_elapsed_{i}'] = '00:00'
        test_dict[f'visit_pp_shots_{i}'] = 0
        test_dict[f'visit_pp_oppshots_{i}'] = 0    
    # Process home team performance data from nu_wih[6]
    df_home_perf = nu_wih[6].iloc[-1, :]  # Last row
    
    # Keep relevant columns ('A', 'Shots By Period', 'BLK')
    columns_to_keep = df_home_perf.loc[df_home_perf.index.get_level_values(0).isin(['A', 'Shots By Period', 'BLK'])]
    
    # Store home team performance data in the dictionary
    for col in columns_to_keep.index:
        if col[0] == 'Shots By Period':
            test_dict[f"home_shots_p{col[1]}"] = columns_to_keep[col]
        else:
            test_dict[f'home_{col[0]}'] = columns_to_keep[col]
    
    # Process visit team performance data from nu_wih[5]
    df_visit_perf = nu_wih[5].iloc[-1, :]  # Last row
    
    # Keep relevant columns ('A', 'Shots By Period', 'BLK')
    columns_to_keep = df_visit_perf.loc[df_visit_perf.index.get_level_values(0).isin(['A', 'Shots By Period', 'BLK'])]
    
    # Store visit team performance data in the dictionary
    for col in columns_to_keep.index:
        if col[0] == 'Shots By Period':
            test_dict[f"visit_shots_p{col[1]}"] = columns_to_keep[col]
        else:
            test_dict[f'visit_{col[0]}'] = columns_to_keep[col]
    
    # Store faceoff wins for home and visit teams
    test_dict['home_faceoff_w'] = nu_wih[9].iloc[-1, -1]  # Last row, last column
    test_dict['visit_faceoff_w'] = nu_wih[9].iloc[-1, -2]  # Last row, second-to-last column

    print(f'Index {idx} worked, moving to {idx+1}')
    full_dict[f'game_{idx}'] = test_dict
# Out:
# Index 0 worked, moving to 1
# Index 1 worked, moving to 2
# Index 2 worked, moving to 3
# Index 3 worked, moving to 4
# Index 4 worked, moving to 5
# Index 5 worked, moving to 6
# Index 6 worked, moving to 7
# Index 7 worked, moving to 8
# Index 8 worked, moving to 9
# Index 9 worked, moving to 10
# Index 10 worked, moving to 11
# Index 11 worked, moving to 12
# Index 12 worked, moving to 13
# Index 13 worked, moving to 14
# Index 14 worked, moving to 15
# Index 15 worked, moving to 16
# Index 16 worked, moving to 17
# Index 17 worked, moving to 18
# Index 18 worked, moving to 19
# Index 19 worked, moving to 20
# Index 20 worked, moving to 21
# Index 21 worked, moving to 22
# Index 22 worked, moving to 23
# Index 23 worked, moving to 24
# Index 24 worked, moving to 25
# Index 25 worked, moving to 26
# Index 26 worked, moving to 27
# Index 27 worked, moving to 28
# Index 28 worked, moving to 29
# Index 29 worked, moving to 30
# Index 30 worked, moving to 31
# Index 31 worked, moving to 32
# Index 32 worked, moving to 33
# Index 33 worked, moving to 34
# Index 34 worked, moving to 35
# Index 35 worked, moving to 36
# Index 36 worked, moving to 37
# Index 37 worked, moving to 38
# Index 38 worked, moving to 39

# %%
full_dict
# Out:
# defaultdict(dict,
#             {'game_0': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Penn St.',
#                           'home_1': 1,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_1': '04:05',
#                           'home_pp_shots_1': 4,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 1,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '00:40',
#                           'home_pp_shots_3': 0,
#                           'home_pp_oppshots_3': 1,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 2,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '04:00',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '00:33',
#                           'visit_pp_shots_3': 0,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 9,
#                           'home_shots_p2': 5,
#                           'home_shots_p3': 9,
#                           'home_BLK': 22,
#                           'visit_A': 0,
#                           'visit_shots_p1': 5,
#                           'visit_shots_p2': 12,
#                           'visit_shots_p3': 10,
#                           'visit_BLK': 14,
#                           'home_faceoff_w': 20,
#                           'visit_faceoff_w': 27}),
#              'game_1': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Penn St.',
#                           'home_1': 1,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 2,
#                           'home_pp_elapsed_1': '02:00',
#                           'home_pp_shots_1': 2,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 3,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_1': '04:00',
#                           'visit_pp_shots_1': 6,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 6,
#                           'home_shots_p2': 12,
#                           'home_shots_p3': 12,
#                           'home_BLK': 24,
#                           'visit_A': 4,
#                           'visit_shots_p1': 17,
#                           'visit_shots_p2': 9,
#                           'visit_shots_p3': 13,
#                           'visit_BLK': 19,
#                           'home_faceoff_w': 26,
#                           'visit_faceoff_w': 35}),
#              'game_2': defaultdict(list,
#                          {'home_team': 'LIU',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 2,
#                           'visit_2': 1,
#                           'visit_3': 3,
#                           'home_pp_elapsed_1': '02:00',
#                           'home_pp_shots_1': 3,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '05:33',
#                           'home_pp_shots_3': 1,
#                           'home_pp_oppshots_3': 1,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 5,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 2,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '01:38',
#                           'visit_pp_shots_3': 3,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 0,
#                           'home_shots_p1': 7,
#                           'home_shots_p2': 9,
#                           'home_shots_p3': 1,
#                           'home_BLK': 11,
#                           'visit_A': 10,
#                           'visit_shots_p1': 21,
#                           'visit_shots_p2': 10,
#                           'visit_shots_p3': 14,
#                           'visit_BLK': 8,
#                           'home_faceoff_w': 24,
#                           'visit_faceoff_w': 20}),
#              'game_3': defaultdict(list,
#                          {'home_team': 'LIU',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 2,
#                           'home_pp_elapsed_1': '04:00',
#                           'home_pp_shots_1': 3,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '06:00',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 6,
#                           'home_pp_elapsed_3': '04:00',
#                           'home_pp_shots_3': 6,
#                           'home_pp_oppshots_3': 1,
#                           'visit_pp_elapsed_3': '04:00',
#                           'visit_pp_shots_3': 4,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 0,
#                           'home_shots_p1': 7,
#                           'home_shots_p2': 3,
#                           'home_shots_p3': 9,
#                           'home_BLK': 20,
#                           'visit_A': 4,
#                           'visit_shots_p1': 7,
#                           'visit_shots_p2': 18,
#                           'visit_shots_p3': 15,
#                           'visit_BLK': 12,
#                           'home_faceoff_w': 26,
#                           'visit_faceoff_w': 21}),
#              'game_4': defaultdict(list,
#                          {'home_team': 'Boston University',
#                           'visit_team': 'Northeastern',
#                           'home_1': 1,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 1,
#                           'visit_3': 2,
#                           'home_pp_elapsed_1': '02:00',
#                           'home_pp_shots_1': 1,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 3,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_2': '00:36',
#                           'visit_pp_shots_2': 1,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '04:00',
#                           'visit_pp_shots_3': 3,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 9,
#                           'home_shots_p2': 10,
#                           'home_shots_p3': 3,
#                           'home_BLK': 8,
#                           'visit_A': 6,
#                           'visit_shots_p1': 6,
#                           'visit_shots_p2': 7,
#                           'visit_shots_p3': 13,
#                           'visit_BLK': 13,
#                           'home_faceoff_w': 36,
#                           'visit_faceoff_w': 18}),
#              'game_5': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Boston U.',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 2,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_2': '02:31',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 1,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_2': '00:31',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 3,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 4,
#                           'home_shots_p1': 12,
#                           'home_shots_p2': 9,
#                           'home_shots_p3': 9,
#                           'home_BLK': 17,
#                           'visit_A': 0,
#                           'visit_shots_p1': 10,
#                           'visit_shots_p2': 11,
#                           'visit_shots_p3': 10,
#                           'visit_BLK': 6,
#                           'home_faceoff_w': 28,
#                           'visit_faceoff_w': 17}),
#              'game_6': defaultdict(list,
#                          {'home_team': 'Merrimack',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 1,
#                           'home_3': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_1': '02:00',
#                           'home_pp_shots_1': 1,
#                           'home_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 1,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 1,
#                           'visit_pp_oppshots_2': 0,
#                           'home_A': 0,
#                           'home_shots_p1': 6,
#                           'home_shots_p2': 4,
#                           'home_shots_p3': 4,
#                           'home_BLK': 17,
#                           'visit_A': 0,
#                           'visit_shots_p1': 6,
#                           'visit_shots_p2': 12,
#                           'visit_shots_p3': 11,
#                           'visit_BLK': 11,
#                           'home_faceoff_w': 20,
#                           'visit_faceoff_w': 26}),
#              'game_7': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'St. Cloud St.',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 2,
#                           'home_pp_elapsed_3': '04:00',
#                           'home_pp_shots_3': 3,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_1': '04:00',
#                           'visit_pp_shots_1': 2,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '04:00',
#                           'visit_pp_shots_2': 4,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 0,
#                           'visit_pp_oppshots_3': 1,
#                           'home_A': 0,
#                           'home_shots_p1': 8,
#                           'home_shots_p2': 4,
#                           'home_shots_p3': 9,
#                           'home_BLK': 23,
#                           'visit_A': 2,
#                           'visit_shots_p1': 7,
#                           'visit_shots_p2': 14,
#                           'visit_shots_p3': 9,
#                           'visit_BLK': 18,
#                           'home_faceoff_w': 27,
#                           'visit_faceoff_w': 24}),
#              'game_8': defaultdict(list,
#                          {'home_team': 'Sacred Heart',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 1,
#                           'visit_1': 3,
#                           'visit_2': 1,
#                           'visit_3': 0,
#                           'home_pp_elapsed_2': '04:00',
#                           'home_pp_shots_2': 4,
#                           'home_pp_oppshots_2': 1,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 1,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 2,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '04:00',
#                           'visit_pp_shots_2': 4,
#                           'visit_pp_oppshots_2': 0,
#                           'home_A': 1,
#                           'home_shots_p1': 6,
#                           'home_shots_p2': 6,
#                           'home_shots_p3': 13,
#                           'home_BLK': 22,
#                           'visit_A': 7,
#                           'visit_shots_p1': 11,
#                           'visit_shots_p2': 11,
#                           'visit_shots_p3': 7,
#                           'visit_BLK': 7,
#                           'home_faceoff_w': 19,
#                           'visit_faceoff_w': 33}),
#              'game_9': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Holy Cross',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'home_OT 1': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'visit_OT 1': 1,
#                           'home_pp_elapsed_1': '02:00',
#                           'home_pp_shots_1': 7,
#                           'home_pp_oppshots_1': 1,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 3,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_4': '01:02',
#                           'visit_pp_shots_4': 3,
#                           'visit_pp_oppshots_4': 0,
#                           'home_A': 0,
#                           'home_shots_p1': 21,
#                           'home_shots_p2': 11,
#                           'home_shots_p3': 7,
#                           'home_shots_p4': 1,
#                           'home_BLK': 7,
#                           'visit_A': 1,
#                           'visit_shots_p1': 4,
#                           'visit_shots_p2': 12,
#                           'visit_shots_p3': 7,
#                           'visit_shots_p4': 3,
#                           'visit_BLK': 20,
#                           'home_faceoff_w': 42,
#                           'visit_faceoff_w': 21}),
#              'game_10': defaultdict(list,
#                          {'home_team': 'Holy Cross',
#                           'visit_team': 'Northeastern',
#                           'home_1': 1,
#                           'home_2': 1,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 1,
#                           'visit_3': 2,
#                           'home_pp_elapsed_1': '00:37',
#                           'home_pp_shots_1': 2,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 1,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '02:39',
#                           'home_pp_shots_3': 2,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_2': '07:16',
#                           'visit_pp_shots_2': 5,
#                           'visit_pp_oppshots_2': 1,
#                           'visit_pp_elapsed_3': '03:54',
#                           'visit_pp_shots_3': 2,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 4,
#                           'home_shots_p1': 4,
#                           'home_shots_p2': 5,
#                           'home_shots_p3': 3,
#                           'home_BLK': 17,
#                           'visit_A': 7,
#                           'visit_shots_p1': 19,
#                           'visit_shots_p2': 11,
#                           'visit_shots_p3': 7,
#                           'visit_BLK': 7,
#                           'home_faceoff_w': 16,
#                           'visit_faceoff_w': 28}),
#              'game_11': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'UConn',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 1,
#                           'visit_3': 1,
#                           'home_pp_elapsed_1': '04:00',
#                           'home_pp_shots_1': 1,
#                           'home_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '03:52',
#                           'visit_pp_shots_2': 4,
#                           'visit_pp_oppshots_2': 2,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 1,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 0,
#                           'home_shots_p1': 6,
#                           'home_shots_p2': 9,
#                           'home_shots_p3': 8,
#                           'home_BLK': 12,
#                           'visit_A': 6,
#                           'visit_shots_p1': 3,
#                           'visit_shots_p2': 10,
#                           'visit_shots_p3': 4,
#                           'visit_BLK': 19,
#                           'home_faceoff_w': 21,
#                           'visit_faceoff_w': 25}),
#              'game_12': defaultdict(list,
#                          {'home_team': 'UConn',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 1,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_3': '00:00',
#                           'home_pp_shots_3': 0,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_3': '00:00',
#                           'visit_pp_shots_3': 0,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 1,
#                           'home_shots_p1': 0,
#                           'home_shots_p2': 0,
#                           'home_shots_p3': 1,
#                           'home_BLK': 9,
#                           'visit_A': 0,
#                           'visit_shots_p1': 4,
#                           'visit_shots_p2': 8,
#                           'visit_shots_p3': 10,
#                           'visit_BLK': 7,
#                           'home_faceoff_w': 22,
#                           'visit_faceoff_w': 24}),
#              'game_13': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Providence',
#                           'home_1': 0,
#                           'home_2': 2,
#                           'home_3': 4,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 0,
#                           'home_pp_elapsed_2': '00:13',
#                           'home_pp_shots_2': 1,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '09:02',
#                           'home_pp_shots_3': 13,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_2': '06:00',
#                           'visit_pp_shots_2': 2,
#                           'visit_pp_oppshots_2': 1,
#                           'home_A': 12,
#                           'home_shots_p1': 12,
#                           'home_shots_p2': 11,
#                           'home_shots_p3': 17,
#                           'home_BLK': 18,
#                           'visit_A': 1,
#                           'visit_shots_p1': 4,
#                           'visit_shots_p2': 12,
#                           'visit_shots_p3': 6,
#                           'visit_BLK': 16,
#                           'home_faceoff_w': 32,
#                           'visit_faceoff_w': 29}),
#              'game_14': defaultdict(list,
#                          {'home_team': 'Providence',
#                           'visit_team': 'Northeastern',
#                           'home_1': 1,
#                           'home_2': 2,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_1': '04:00',
#                           'home_pp_shots_1': 2,
#                           'home_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 1,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 6,
#                           'home_shots_p1': 10,
#                           'home_shots_p2': 11,
#                           'home_shots_p3': 7,
#                           'home_BLK': 15,
#                           'visit_A': 2,
#                           'visit_shots_p1': 8,
#                           'visit_shots_p2': 6,
#                           'visit_shots_p3': 3,
#                           'visit_BLK': 12,
#                           'home_faceoff_w': 25,
#                           'visit_faceoff_w': 32}),
#              'game_15': defaultdict(list,
#                          {'home_team': 'Vermont',
#                           'visit_team': 'Northeastern',
#                           'home_1': 1,
#                           'home_2': 1,
#                           'home_3': 1,
#                           'visit_1': 0,
#                           'visit_2': 2,
#                           'visit_3': 0,
#                           'home_pp_elapsed_1': '02:36',
#                           'home_pp_shots_1': 1,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 4,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_1': '00:36',
#                           'visit_pp_shots_1': 2,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:51',
#                           'visit_pp_shots_2': 7,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 1,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 5,
#                           'home_shots_p1': 8,
#                           'home_shots_p2': 6,
#                           'home_shots_p3': 10,
#                           'home_BLK': 22,
#                           'visit_A': 1,
#                           'visit_shots_p1': 5,
#                           'visit_shots_p2': 14,
#                           'visit_shots_p3': 7,
#                           'visit_BLK': 12,
#                           'home_faceoff_w': 28,
#                           'visit_faceoff_w': 24}),
#              'game_16': defaultdict(list,
#                          {'home_team': 'Boston College',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 1,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 0,
#                           'visit_3': 2,
#                           'home_pp_elapsed_2': '03:31',
#                           'home_pp_shots_2': 3,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 3,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '00:47',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '03:45',
#                           'visit_pp_shots_3': 1,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 0,
#                           'home_shots_p2': 1,
#                           'home_shots_p3': 0,
#                           'home_BLK': 10,
#                           'visit_A': 6,
#                           'visit_shots_p1': 1,
#                           'visit_shots_p2': 0,
#                           'visit_shots_p3': 2,
#                           'visit_BLK': 6,
#                           'home_faceoff_w': 39,
#                           'visit_faceoff_w': 28}),
#              'game_17': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Providence',
#                           'home_1': 1,
#                           'home_2': 2,
#                           'home_3': 1,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 1,
#                           'home_pp_elapsed_2': '01:16',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 1,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 2,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 2,
#                           'visit_pp_oppshots_3': 1,
#                           'home_A': 8,
#                           'home_shots_p1': 17,
#                           'home_shots_p2': 9,
#                           'home_shots_p3': 6,
#                           'home_BLK': 15,
#                           'visit_A': 4,
#                           'visit_shots_p1': 8,
#                           'visit_shots_p2': 10,
#                           'visit_shots_p3': 10,
#                           'visit_BLK': 7,
#                           'home_faceoff_w': 24,
#                           'visit_faceoff_w': 29}),
#              'game_18': defaultdict(list,
#                          {'home_team': 'Boston University',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 1,
#                           'home_3': 0,
#                           'home_OT 1': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 1,
#                           'visit_OT 1': 1,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 3,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_3': '00:00',
#                           'visit_pp_shots_3': 0,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 7,
#                           'home_shots_p2': 10,
#                           'home_shots_p3': 8,
#                           'home_shots_p4': 2,
#                           'home_BLK': 6,
#                           'visit_A': 2,
#                           'visit_shots_p1': 9,
#                           'visit_shots_p2': 5,
#                           'visit_shots_p3': 6,
#                           'visit_shots_p4': 3,
#                           'visit_BLK': 17,
#                           'home_faceoff_w': 20,
#                           'visit_faceoff_w': 28}),
#              'game_19': defaultdict(list,
#                          {'home_team': 'Yale',
#                           'visit_team': 'Northeastern',
#                           'home_1': 1,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'home_OT 1': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 1,
#                           'visit_OT 1': 1,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 1,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 0,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_3': '00:34',
#                           'visit_pp_shots_3': 2,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 17,
#                           'home_shots_p2': 15,
#                           'home_shots_p3': 10,
#                           'home_shots_p4': 4,
#                           'home_BLK': 8,
#                           'visit_A': 3,
#                           'visit_shots_p1': 5,
#                           'visit_shots_p2': 5,
#                           'visit_shots_p3': 6,
#                           'visit_shots_p4': 3,
#                           'visit_BLK': 13,
#                           'home_faceoff_w': 29,
#                           'visit_faceoff_w': 15}),
#              'game_20': defaultdict(list,
#                          {'home_team': 'Holy Cross',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 1,
#                           'home_3': 0,
#                           'visit_1': 2,
#                           'visit_2': 3,
#                           'visit_3': 1,
#                           'home_pp_elapsed_2': '05:10',
#                           'home_pp_shots_2': 3,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_2': '06:32',
#                           'visit_pp_shots_2': 8,
#                           'visit_pp_oppshots_2': 1,
#                           'home_A': 2,
#                           'home_shots_p1': 8,
#                           'home_shots_p2': 5,
#                           'home_shots_p3': 8,
#                           'home_BLK': 13,
#                           'visit_A': 12,
#                           'visit_shots_p1': 10,
#                           'visit_shots_p2': 13,
#                           'visit_shots_p3': 8,
#                           'visit_BLK': 8,
#                           'home_faceoff_w': 25,
#                           'visit_faceoff_w': 35}),
#              'game_21': defaultdict(list,
#                          {'home_team': 'Maine',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'home_OT 1': 1,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'visit_OT 1': 0,
#                           'home_pp_elapsed_2': '02:48',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 2,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 1,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:48',
#                           'visit_pp_shots_2': 3,
#                           'visit_pp_oppshots_2': 1,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 0,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 1,
#                           'home_shots_p1': 7,
#                           'home_shots_p2': 13,
#                           'home_shots_p3': 10,
#                           'home_shots_p4': 1,
#                           'home_BLK': 10,
#                           'visit_A': 0,
#                           'visit_shots_p1': 7,
#                           'visit_shots_p2': 9,
#                           'visit_shots_p3': 5,
#                           'visit_shots_p4': 0,
#                           'visit_BLK': 9,
#                           'home_faceoff_w': 25,
#                           'visit_faceoff_w': 28}),
#              'game_22': defaultdict(list,
#                          {'home_team': 'Maine',
#                           'visit_team': 'Northeastern',
#                           'home_1': 1,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'home_OT 1': 0,
#                           'home_OT 2': 0,
#                           'visit_1': 1,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'visit_OT 1': 0,
#                           'visit_OT 2': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 3,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 1,
#                           'visit_pp_oppshots_1': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 6,
#                           'home_shots_p2': 14,
#                           'home_shots_p3': 8,
#                           'home_shots_p4': 4,
#                           'home_shots_p5': 0,
#                           'home_BLK': 15,
#                           'visit_A': 1,
#                           'visit_shots_p1': 11,
#                           'visit_shots_p2': 5,
#                           'visit_shots_p3': 7,
#                           'visit_shots_p4': 1,
#                           'visit_shots_p5': 0,
#                           'visit_BLK': 23,
#                           'home_faceoff_w': 28,
#                           'visit_faceoff_w': 26}),
#              'game_23': defaultdict(list,
#                          {'home_team': 'Harvard',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_1': '04:00',
#                           'home_pp_shots_1': 3,
#                           'home_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_1': '01:57',
#                           'visit_pp_shots_1': 4,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 1,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 0,
#                           'home_shots_p1': 4,
#                           'home_shots_p2': 4,
#                           'home_shots_p3': 1,
#                           'home_BLK': 30,
#                           'visit_A': 2,
#                           'visit_shots_p1': 12,
#                           'visit_shots_p2': 14,
#                           'visit_shots_p3': 14,
#                           'visit_BLK': 11,
#                           'home_faceoff_w': 27,
#                           'visit_faceoff_w': 23}),
#              'game_24': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'New Hampshire',
#                           'home_1': 2,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_3': '00:00',
#                           'home_pp_shots_3': 0,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 1,
#                           'visit_pp_oppshots_2': 1,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 1,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 3,
#                           'home_shots_p1': 10,
#                           'home_shots_p2': 8,
#                           'home_shots_p3': 12,
#                           'home_BLK': 13,
#                           'visit_A': 2,
#                           'visit_shots_p1': 8,
#                           'visit_shots_p2': 11,
#                           'visit_shots_p3': 6,
#                           'visit_BLK': 16,
#                           'home_faceoff_w': 23,
#                           'visit_faceoff_w': 24}),
#              'game_25': defaultdict(list,
#                          {'home_team': 'Boston U.',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 1,
#                           'home_OT 1': 0,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 0,
#                           'visit_OT 1': 1,
#                           'home_pp_elapsed_1': '04:00',
#                           'home_pp_shots_1': 2,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '04:00',
#                           'home_pp_shots_2': 3,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 3,
#                           'visit_pp_oppshots_1': 1,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 3,
#                           'visit_pp_oppshots_2': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 7,
#                           'home_shots_p2': 12,
#                           'home_shots_p3': 5,
#                           'home_shots_p4': 0,
#                           'home_BLK': 9,
#                           'visit_A': 4,
#                           'visit_shots_p1': 8,
#                           'visit_shots_p2': 9,
#                           'visit_shots_p3': 12,
#                           'visit_shots_p4': 1,
#                           'visit_BLK': 13,
#                           'home_faceoff_w': 26,
#                           'visit_faceoff_w': 21}),
#              'game_26': defaultdict(list,
#                          {'home_team': 'Merrimack',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 1,
#                           'visit_2': 1,
#                           'visit_3': 2,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_1': '01:00',
#                           'visit_pp_shots_1': 4,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 0,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 0,
#                           'home_shots_p1': 4,
#                           'home_shots_p2': 6,
#                           'home_shots_p3': 2,
#                           'home_BLK': 11,
#                           'visit_A': 7,
#                           'visit_shots_p1': 10,
#                           'visit_shots_p2': 4,
#                           'visit_shots_p3': 12,
#                           'visit_BLK': 8,
#                           'home_faceoff_w': 19,
#                           'visit_faceoff_w': 24}),
#              'game_27': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Merrimack',
#                           'home_1': 2,
#                           'home_2': 1,
#                           'home_3': 1,
#                           'visit_1': 2,
#                           'visit_2': 0,
#                           'visit_3': 1,
#                           'home_pp_elapsed_1': '02:00',
#                           'home_pp_shots_1': 2,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 1,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 0,
#                           'home_A': 7,
#                           'home_shots_p1': 12,
#                           'home_shots_p2': 8,
#                           'home_shots_p3': 8,
#                           'home_BLK': 7,
#                           'visit_A': 6,
#                           'visit_shots_p1': 6,
#                           'visit_shots_p2': 3,
#                           'visit_shots_p3': 5,
#                           'visit_BLK': 11,
#                           'home_faceoff_w': 24,
#                           'visit_faceoff_w': 24}),
#              'game_28': defaultdict(list,
#                          {'home_team': 'New Hampshire',
#                           'visit_team': 'Northeastern',
#                           'home_1': 2,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'home_OT 1': 0,
#                           'visit_1': 1,
#                           'visit_2': 0,
#                           'visit_3': 1,
#                           'visit_OT 1': 1,
#                           'home_pp_elapsed_1': '03:47',
#                           'home_pp_shots_1': 4,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '04:00',
#                           'home_pp_shots_2': 2,
#                           'home_pp_oppshots_2': 2,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 3,
#                           'home_pp_oppshots_3': 1,
#                           'visit_pp_elapsed_1': '04:00',
#                           'visit_pp_shots_1': 6,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_3': '00:18',
#                           'visit_pp_shots_3': 2,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 4,
#                           'home_shots_p1': 10,
#                           'home_shots_p2': 8,
#                           'home_shots_p3': 10,
#                           'home_shots_p4': 0,
#                           'home_BLK': 12,
#                           'visit_A': 5,
#                           'visit_shots_p1': 9,
#                           'visit_shots_p2': 7,
#                           'visit_shots_p3': 9,
#                           'visit_shots_p4': 3,
#                           'visit_BLK': 18,
#                           'home_faceoff_w': 37,
#                           'visit_faceoff_w': 26}),
#              'game_29': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'New Hampshire',
#                           'home_1': 1,
#                           'home_2': 0,
#                           'home_3': 2,
#                           'home_OT 1': 1,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 3,
#                           'visit_OT 1': 0,
#                           'home_pp_elapsed_2': '02:00',
#                           'home_pp_shots_2': 1,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '05:00',
#                           'home_pp_shots_3': 5,
#                           'home_pp_oppshots_3': 3,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 5,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 4,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 2,
#                           'visit_pp_oppshots_3': 1,
#                           'home_A': 8,
#                           'home_shots_p1': 7,
#                           'home_shots_p2': 7,
#                           'home_shots_p3': 16,
#                           'home_shots_p4': 1,
#                           'home_BLK': 9,
#                           'visit_A': 5,
#                           'visit_shots_p1': 13,
#                           'visit_shots_p2': 8,
#                           'visit_shots_p3': 10,
#                           'visit_shots_p4': 0,
#                           'visit_BLK': 20,
#                           'home_faceoff_w': 29,
#                           'visit_faceoff_w': 30}),
#              'game_30': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'UConn',
#                           'home_1': 1,
#                           'home_2': 1,
#                           'home_3': 0,
#                           'home_OT 1': 0,
#                           'home_OT 2': 0,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 1,
#                           'visit_OT 1': 0,
#                           'visit_OT 2': 0,
#                           'home_pp_elapsed_1': '00:55',
#                           'home_pp_shots_1': 1,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_3': '04:00',
#                           'home_pp_shots_3': 0,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_1': '00:55',
#                           'visit_pp_shots_1': 1,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 1,
#                           'visit_pp_elapsed_4': '15:21',
#                           'visit_pp_shots_4': 0,
#                           'visit_pp_oppshots_4': 0,
#                           'home_A': 4,
#                           'home_shots_p1': 9,
#                           'home_shots_p2': 12,
#                           'home_shots_p3': 9,
#                           'home_shots_p4': 3,
#                           'home_shots_p5': 0,
#                           'home_BLK': 16,
#                           'visit_A': 4,
#                           'visit_shots_p1': 7,
#                           'visit_shots_p2': 13,
#                           'visit_shots_p3': 6,
#                           'visit_shots_p4': 3,
#                           'visit_shots_p5': 0,
#                           'visit_BLK': 9,
#                           'home_faceoff_w': 30,
#                           'visit_faceoff_w': 30}),
#              'game_31': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Maine',
#                           'home_1': 2,
#                           'home_2': 1,
#                           'home_3': 1,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'home_pp_elapsed_1': '01:41',
#                           'home_pp_shots_1': 4,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 1,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 0,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 4,
#                           'home_shots_p1': 17,
#                           'home_shots_p2': 11,
#                           'home_shots_p3': 8,
#                           'home_BLK': 14,
#                           'visit_A': 0,
#                           'visit_shots_p1': 7,
#                           'visit_shots_p2': 10,
#                           'visit_shots_p3': 2,
#                           'visit_BLK': 21,
#                           'home_faceoff_w': 26,
#                           'visit_faceoff_w': 18}),
#              'game_32': defaultdict(list,
#                          {'home_team': 'Boston College',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 1,
#                           'home_3': 1,
#                           'home_OT 1': 0,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 1,
#                           'visit_OT 1': 1,
#                           'home_pp_elapsed_2': '02:42',
#                           'home_pp_shots_2': 3,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 2,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '00:32',
#                           'visit_pp_shots_2': 1,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '04:00',
#                           'visit_pp_shots_3': 3,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 3,
#                           'home_shots_p1': 9,
#                           'home_shots_p2': 9,
#                           'home_shots_p3': 10,
#                           'home_shots_p4': 1,
#                           'home_BLK': 16,
#                           'visit_A': 6,
#                           'visit_shots_p1': 0,
#                           'visit_shots_p2': 1,
#                           'visit_shots_p3': 1,
#                           'visit_shots_p4': 1,
#                           'visit_BLK': 5,
#                           'home_faceoff_w': 30,
#                           'visit_faceoff_w': 38}),
#              'game_33': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Boston College',
#                           'home_1': 3,
#                           'home_2': 2,
#                           'home_3': 0,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 0,
#                           'home_pp_elapsed_1': '00:25',
#                           'home_pp_shots_1': 3,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_3': '06:45',
#                           'home_pp_shots_3': 2,
#                           'home_pp_oppshots_3': 2,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 3,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '04:00',
#                           'visit_pp_shots_2': 7,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '01:45',
#                           'visit_pp_shots_3': 2,
#                           'visit_pp_oppshots_3': 0,
#                           'home_A': 10,
#                           'home_shots_p1': 12,
#                           'home_shots_p2': 8,
#                           'home_shots_p3': 6,
#                           'home_BLK': 18,
#                           'visit_A': 1,
#                           'visit_shots_p1': 15,
#                           'visit_shots_p2': 16,
#                           'visit_shots_p3': 14,
#                           'visit_BLK': 11,
#                           'home_faceoff_w': 34,
#                           'visit_faceoff_w': 24}),
#              'game_34': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Vermont',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 1,
#                           'home_pp_elapsed_1': '04:00',
#                           'home_pp_shots_1': 9,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_3': '02:00',
#                           'home_pp_shots_3': 1,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 1,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '01:06',
#                           'visit_pp_shots_2': 1,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:00',
#                           'visit_pp_shots_3': 1,
#                           'visit_pp_oppshots_3': 1,
#                           'home_A': 0,
#                           'home_shots_p1': 8,
#                           'home_shots_p2': 13,
#                           'home_shots_p3': 8,
#                           'home_BLK': 8,
#                           'visit_A': 3,
#                           'visit_shots_p1': 6,
#                           'visit_shots_p2': 4,
#                           'visit_shots_p3': 7,
#                           'visit_BLK': 17,
#                           'home_faceoff_w': 18,
#                           'visit_faceoff_w': 26}),
#              'game_35': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Vermont',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 1,
#                           'home_OT 1': 0,
#                           'home_OT 2': 0,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 1,
#                           'visit_OT 1': 0,
#                           'visit_OT 2': 0,
#                           'home_pp_elapsed_1': '06:00',
#                           'home_pp_shots_1': 4,
#                           'home_pp_oppshots_1': 1,
#                           'home_pp_elapsed_2': '02:13',
#                           'home_pp_shots_2': 0,
#                           'home_pp_oppshots_2': 1,
#                           'home_pp_elapsed_3': '01:13',
#                           'home_pp_shots_3': 3,
#                           'home_pp_oppshots_3': 0,
#                           'visit_pp_elapsed_1': '02:00',
#                           'visit_pp_shots_1': 0,
#                           'visit_pp_oppshots_1': 0,
#                           'visit_pp_elapsed_2': '02:13',
#                           'visit_pp_shots_2': 4,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_3': '02:28',
#                           'visit_pp_shots_3': 4,
#                           'visit_pp_oppshots_3': 2,
#                           'home_A': 2,
#                           'home_shots_p1': 9,
#                           'home_shots_p2': 9,
#                           'home_shots_p3': 8,
#                           'home_shots_p4': 6,
#                           'home_shots_p5': 0,
#                           'home_BLK': 8,
#                           'visit_A': 2,
#                           'visit_shots_p1': 5,
#                           'visit_shots_p2': 10,
#                           'visit_shots_p3': 10,
#                           'visit_shots_p4': 3,
#                           'visit_shots_p5': 0,
#                           'visit_BLK': 17,
#                           'home_faceoff_w': 19,
#                           'visit_faceoff_w': 31}),
#              'game_36': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'Merrimack',
#                           'home_1': 0,
#                           'home_2': 2,
#                           'home_3': 2,
#                           'visit_1': 0,
#                           'visit_2': 1,
#                           'visit_3': 0,
#                           'home_pp_elapsed_2': '04:00',
#                           'home_pp_shots_2': 4,
#                           'home_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 2,
#                           'home_A': 8,
#                           'home_shots_p1': 4,
#                           'home_shots_p2': 20,
#                           'home_shots_p3': 15,
#                           'home_BLK': 16,
#                           'visit_A': 1,
#                           'visit_shots_p1': 8,
#                           'visit_shots_p2': 7,
#                           'visit_shots_p3': 7,
#                           'visit_BLK': 19,
#                           'home_faceoff_w': 25,
#                           'visit_faceoff_w': 30}),
#              'game_37': defaultdict(list,
#                          {'home_team': 'Northeastern',
#                           'visit_team': 'New Hampshire',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 4,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 1,
#                           'home_pp_elapsed_1': '02:00',
#                           'home_pp_shots_1': 1,
#                           'home_pp_oppshots_1': 0,
#                           'home_pp_elapsed_2': '00:16',
#                           'home_pp_shots_2': 0,
#                           'home_pp_oppshots_2': 0,
#                           'home_pp_elapsed_3': '03:59',
#                           'home_pp_shots_3': 7,
#                           'home_pp_oppshots_3': 1,
#                           'visit_pp_elapsed_2': '00:16',
#                           'visit_pp_shots_2': 0,
#                           'visit_pp_oppshots_2': 1,
#                           'visit_pp_elapsed_3': '07:00',
#                           'visit_pp_shots_3': 8,
#                           'visit_pp_oppshots_3': 1,
#                           'home_A': 7,
#                           'home_shots_p1': 9,
#                           'home_shots_p2': 7,
#                           'home_shots_p3': 16,
#                           'home_BLK': 14,
#                           'visit_A': 0,
#                           'visit_shots_p1': 9,
#                           'visit_shots_p2': 6,
#                           'visit_shots_p3': 14,
#                           'visit_BLK': 19,
#                           'home_faceoff_w': 30,
#                           'visit_faceoff_w': 22}),
#              'game_38': defaultdict(list,
#                          {'home_team': 'UConn',
#                           'visit_team': 'Northeastern',
#                           'home_1': 0,
#                           'home_2': 0,
#                           'home_3': 0,
#                           'home_OT 1': 1,
#                           'visit_1': 0,
#                           'visit_2': 0,
#                           'visit_3': 0,
#                           'visit_OT 1': 0,
#                           'home_pp_elapsed_3': '09:00',
#                           'home_pp_shots_3': 9,
#                           'home_pp_oppshots_3': 2,
#                           'visit_pp_elapsed_2': '02:00',
#                           'visit_pp_shots_2': 4,
#                           'visit_pp_oppshots_2': 0,
#                           'visit_pp_elapsed_4': '02:00',
#                           'visit_pp_shots_4': 3,
#                           'visit_pp_oppshots_4': 0,
#                           'home_A': 2,
#                           'home_shots_p1': 10,
#                           'home_shots_p2': 13,
#                           'home_shots_p3': 15,
#                           'home_shots_p4': 14,
#                           'home_BLK': 24,
#                           'visit_A': 0,
#                           'visit_shots_p1': 10,
#                           'visit_shots_p2': 9,
#                           'visit_shots_p3': 8,
#                           'visit_shots_p4': 11,
#                           'visit_BLK': 13,
#                           'home_faceoff_w': 36,
#                           'visit_faceoff_w': 40})})

# %%
# Convert the nested dictionary into a DataFrame
df_2023_24 = pd.DataFrame.from_dict(full_dict, orient='index')

# Display the DataFrame
df_2023_24
# Out:
#                  home_team      visit_team  home_1  home_2  home_3  visit_1  \
# game_0        Northeastern        Penn St.       1       0       0        0
# game_1        Northeastern        Penn St.       1       0       0        0
# game_2                 LIU    Northeastern       0       0       0        2
# game_3                 LIU    Northeastern       0       0       0        0
# game_4   Boston University    Northeastern       1       0       0        1
# game_5        Northeastern       Boston U.       0       0       2        0
# game_6           Merrimack    Northeastern       0       1       0        0
# game_7        Northeastern   St. Cloud St.       0       0       0        0
# game_8        Sacred Heart    Northeastern       0       0       1        3
# game_9        Northeastern      Holy Cross       0       0       0        0
# game_10         Holy Cross    Northeastern       1       1       0        1
# game_11       Northeastern           UConn       0       0       0        1
# game_12              UConn    Northeastern       0       0       1        0
# game_13       Northeastern      Providence       0       2       4        0
# game_14         Providence    Northeastern       1       2       0        1
# game_15            Vermont    Northeastern       1       1       1        0
# game_16     Boston College    Northeastern       0       1       0        1
# game_17       Northeastern      Providence       1       2       1        0
# game_18  Boston University    Northeastern       0       1       0        0
# game_19               Yale    Northeastern       1       0       0        0
# game_20         Holy Cross    Northeastern       0       1       0        2
# game_21              Maine    Northeastern       0       0       0        0
# game_22              Maine    Northeastern       1       0       0        1
# game_23            Harvard    Northeastern       0       0       0        1
# game_24       Northeastern   New Hampshire       2       0       0        1
# game_25          Boston U.    Northeastern       0       0       1        0
# game_26          Merrimack    Northeastern       0       0       0        1
# game_27       Northeastern       Merrimack       2       1       1        2
# game_28      New Hampshire    Northeastern       2       0       0        1
# game_29       Northeastern   New Hampshire       1       0       2        0
# game_30       Northeastern           UConn       1       1       0        0
# game_31       Northeastern           Maine       2       1       1        0
# game_32     Boston College    Northeastern       0       1       1        0
# game_33       Northeastern  Boston College       3       2       0        0
# game_34       Northeastern         Vermont       0       0       0        0
# game_35       Northeastern         Vermont       0       0       1        0
# game_36       Northeastern       Merrimack       0       2       2        0
# game_37       Northeastern   New Hampshire       0       0       4        0
# game_38              UConn    Northeastern       0       0       0        0
#
#          visit_2  visit_3 home_pp_elapsed_1  home_pp_shots_1  ...  visit_OT 1  \
# game_0         0        0             04:05              4.0  ...         NaN
# game_1         0        2             02:00              2.0  ...         NaN
# game_2         1        3             02:00              3.0  ...         NaN
# game_3         0        2             04:00              3.0  ...         NaN
# game_4         1        2             02:00              1.0  ...         NaN
# game_5         0        0               NaN              NaN  ...         NaN
# game_6         0        0             02:00              1.0  ...         NaN
# game_7         0        2               NaN              NaN  ...         NaN
# game_8         1        0               NaN              NaN  ...         NaN
# game_9         0        0             02:00              7.0  ...         1.0
# game_10        1        2             00:37              2.0  ...         NaN
# game_11        1        1             04:00              1.0  ...         NaN
# game_12        0        0               NaN              NaN  ...         NaN
# game_13        1        0               NaN              NaN  ...         NaN
# game_14        0        0             04:00              2.0  ...         NaN
# game_15        2        0             02:36              1.0  ...         NaN
# game_16        0        2               NaN              NaN  ...         NaN
# game_17        1        1               NaN              NaN  ...         NaN
# game_18        0        1               NaN              NaN  ...         1.0
# game_19        0        1               NaN              NaN  ...         1.0
# game_20        3        1               NaN              NaN  ...         NaN
# game_21        0        0               NaN              NaN  ...         0.0
# game_22        0        0               NaN              NaN  ...         0.0
# game_23        0        0             04:00              3.0  ...         NaN
# game_24        0        0               NaN              NaN  ...         NaN
# game_25        1        0             04:00              2.0  ...         1.0
# game_26        1        2               NaN              NaN  ...         NaN
# game_27        0        1             02:00              2.0  ...         NaN
# game_28        0        1             03:47              4.0  ...         1.0
# game_29        0        3               NaN              NaN  ...         0.0
# game_30        1        1             00:55              1.0  ...         0.0
# game_31        0        0             01:41              4.0  ...         NaN
# game_32        1        1               NaN              NaN  ...         1.0
# game_33        1        0             00:25              3.0  ...         NaN
# game_34        1        1             04:00              9.0  ...         NaN
# game_35        0        1             06:00              4.0  ...         0.0
# game_36        1        0               NaN              NaN  ...         NaN
# game_37        0        1             02:00              1.0  ...         NaN
# game_38        0        0               NaN              NaN  ...         0.0
#
#         visit_pp_elapsed_4  visit_pp_shots_4  visit_pp_oppshots_4  \
# game_0                 NaN               NaN                  NaN
# game_1                 NaN               NaN                  NaN
# game_2                 NaN               NaN                  NaN
# game_3                 NaN               NaN                  NaN
# game_4                 NaN               NaN                  NaN
# game_5                 NaN               NaN                  NaN
# game_6                 NaN               NaN                  NaN
# game_7                 NaN               NaN                  NaN
# game_8                 NaN               NaN                  NaN
# game_9               01:02               3.0                  0.0
# game_10                NaN               NaN                  NaN
# game_11                NaN               NaN                  NaN
# game_12                NaN               NaN                  NaN
# game_13                NaN               NaN                  NaN
# game_14                NaN               NaN                  NaN
# game_15                NaN               NaN                  NaN
# game_16                NaN               NaN                  NaN
# game_17                NaN               NaN                  NaN
# game_18                NaN               NaN                  NaN
# game_19                NaN               NaN                  NaN
# game_20                NaN               NaN                  NaN
# game_21                NaN               NaN                  NaN
# game_22                NaN               NaN                  NaN
# game_23                NaN               NaN                  NaN
# game_24                NaN               NaN                  NaN
# game_25                NaN               NaN                  NaN
# game_26                NaN               NaN                  NaN
# game_27                NaN               NaN                  NaN
# game_28                NaN               NaN                  NaN
# game_29                NaN               NaN                  NaN
# game_30              15:21               0.0                  0.0
# game_31                NaN               NaN                  NaN
# game_32                NaN               NaN                  NaN
# game_33                NaN               NaN                  NaN
# game_34                NaN               NaN                  NaN
# game_35                NaN               NaN                  NaN
# game_36                NaN               NaN                  NaN
# game_37                NaN               NaN                  NaN
# game_38              02:00               3.0                  0.0
#
#         home_shots_p4  visit_shots_p4  home_OT 2 visit_OT 2  home_shots_p5  \
# game_0            NaN             NaN        NaN        NaN            NaN
# game_1            NaN             NaN        NaN        NaN            NaN
# game_2            NaN             NaN        NaN        NaN            NaN
# game_3            NaN             NaN        NaN        NaN            NaN
# game_4            NaN             NaN        NaN        NaN            NaN
# game_5            NaN             NaN        NaN        NaN            NaN
# game_6            NaN             NaN        NaN        NaN            NaN
# game_7            NaN             NaN        NaN        NaN            NaN
# game_8            NaN             NaN        NaN        NaN            NaN
# game_9            1.0             3.0        NaN        NaN            NaN
# game_10           NaN             NaN        NaN        NaN            NaN
# game_11           NaN             NaN        NaN        NaN            NaN
# game_12           NaN             NaN        NaN        NaN            NaN
# game_13           NaN             NaN        NaN        NaN            NaN
# game_14           NaN             NaN        NaN        NaN            NaN
# game_15           NaN             NaN        NaN        NaN            NaN
# game_16           NaN             NaN        NaN        NaN            NaN
# game_17           NaN             NaN        NaN        NaN            NaN
# game_18           2.0             3.0        NaN        NaN            NaN
# game_19           4.0             3.0        NaN        NaN            NaN
# game_20           NaN             NaN        NaN        NaN            NaN
# game_21           1.0             0.0        NaN        NaN            NaN
# game_22           4.0             1.0        0.0        0.0            0.0
# game_23           NaN             NaN        NaN        NaN            NaN
# game_24           NaN             NaN        NaN        NaN            NaN
# game_25           0.0             1.0        NaN        NaN            NaN
# game_26           NaN             NaN        NaN        NaN            NaN
# game_27           NaN             NaN        NaN        NaN            NaN
# game_28           0.0             3.0        NaN        NaN            NaN
# game_29           1.0             0.0        NaN        NaN            NaN
# game_30           3.0             3.0        0.0        0.0            0.0
# game_31           NaN             NaN        NaN        NaN            NaN
# game_32           1.0             1.0        NaN        NaN            NaN
# game_33           NaN             NaN        NaN        NaN            NaN
# game_34           NaN             NaN        NaN        NaN            NaN
# game_35           6.0             3.0        0.0        0.0            0.0
# game_36           NaN             NaN        NaN        NaN            NaN
# game_37           NaN             NaN        NaN        NaN            NaN
# game_38          14.0            11.0        NaN        NaN            NaN
#
#          visit_shots_p5
# game_0              NaN
# game_1              NaN
# game_2              NaN
# game_3              NaN
# game_4              NaN
# game_5              NaN
# game_6              NaN
# game_7              NaN
# game_8              NaN
# game_9              NaN
# game_10             NaN
# game_11             NaN
# game_12             NaN
# game_13             NaN
# game_14             NaN
# game_15             NaN
# game_16             NaN
# game_17             NaN
# game_18             NaN
# game_19             NaN
# game_20             NaN
# game_21             NaN
# game_22             0.0
# game_23             NaN
# game_24             NaN
# game_25             NaN
# game_26             NaN
# game_27             NaN
# game_28             NaN
# game_29             NaN
# game_30             0.0
# game_31             NaN
# game_32             NaN
# game_33             NaN
# game_34             NaN
# game_35             0.0
# game_36             NaN
# game_37             NaN
# game_38             NaN
#
# [39 rows x 49 columns]
